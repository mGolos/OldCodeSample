# %% [markdown]
# # Libraries & adresses

# %%
# %pylab inline
import tools as disp
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
dir1 = "/home/golos/Main/Connectomes/Hagmann/"
dir2 = "/home/golos/Main/Programs/Regions/"
centers = loadtxt(dir1 + 'Centers_Deco_998.txt', dtype=str)[:,1:].astype(float)
labels = loadtxt(dir1 + 'Centers_Deco_998.txt', dtype=str)[:,0]

# %% [markdown]
# # Chargement
# * deux tailles de parcellation : 66 et 998 noeuds
# * un connectome "moyen" (0) et ceux des 5 sujets (1-5)

# %%
SC66, SC998 = [], []
for i in range(6):
    SC66.append( load(dir1 + 'SC_D_66_%i.npy'%i) )
    SC998.append( load(dir1 + 'SC_D_998_%i.npy'%i) )

# %% [markdown]
# # Visualisation

# %% [markdown]
# ## Connectomes

# %%
f,a = subplots(2,6, figsize=(12,3))
for i in range(6):
    a[0,i].spy(SC66[i])
    a[1,i].spy(SC998[i])

# %%
f,a = subplots(2,6, figsize=(12,3))
for i in range(6):
    a[0,i].imshow(SC66[i], interpolation='nearest')
    a[1,i].imshow(SC998[i], interpolation='nearest')

# %% [markdown]
# ## Parcellation 998
# * vues par défaut : extérieure gauche, postérieure, supérieure (devant en haut), extérieure droite
# * intext=True : extérieure gauche, intérieure gauche, intérieure droite, extérieure droite

# %%
disp.parcelFromCenters(arange(998.), centers, fs=(7,1))
disp.parcelFromCenters(arange(998.), centers, fs=(7,1), intext=1)

# %%
patts = disp.kmeans(SC998[0], 4)[0]
for patt in patts:
    disp.parcelFromCenters(patt, centers, fs=(7,1))

# %% [markdown]
# ## Parcellation 66
# * à partir de vecteur de 66 noeuds
# * ou à partir de vecteur 998 noeuds sous-echantillonés dans la fonction

# %%
patts = disp.kmeans(SC66[0], 4)[0]
for patt in patts:
    disp.hagmannParcellation(patt, adress=dir2)

# %% [markdown]
# ### sous-échantillonage

# %%
patts = disp.kmeans(SC998[0], 4)[0]

# %%
i = 3
disp.parcelFromCenters(patts[i], centers, fs=(4,2.8), intext=True, lign=False)
disp.hagmannParcellation(patts[i], adress=dir2)
